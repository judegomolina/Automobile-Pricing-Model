# %% [markdown]
# We first load our model as follows:

# %%
from Automobile_Pricing_Module import *
model = Automobile_Model('model', 'scaler')

# %% [markdown]
# Now we'll preprocess and make the predictions for the new data. Whenever you need to make new predictions you can just change the file path below.

# %%
file_path = 'new_data.csv'
model.load_and_clean_data(file_path)
model.predicted_output()
# Out:
#     Unnamed: 0  symboling  normalized-losses         make fuel-type  \
# 0            0          3                158  alfa-romero       gas
# 1            1          3                158  alfa-romero       gas
# 2            2          1                158  alfa-romero       gas
# 3            3          2                164         audi       gas
# 4            4          2                164         audi       gas
# 5            5          2                158         audi       gas
# 6            6          1                158         audi       gas
# 7            7          1                164         audi       gas
# 8            8          1                158         audi       gas
# 9            9          0                158         audi       gas
# 10          10          2                192          bmw       gas
#
#    aspiration num-of-doors   body-style drive-wheels engine-location  ...  \
# 0         std          two  convertible          rwd           front  ...
# ...
